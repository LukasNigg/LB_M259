# %% [markdown]
# # Aufgabe 4.1
#
# Im Notizbuch "model.ipynb" habe ich überprüft, welche Spalten besonders aussagekräftig sind. Offensichtlich ist die Spalte "victory_status" am aussagekräftigsten.
#
# ![evaluation_4.1.png](attachment:evaluation_4.1.png)

# %% [markdown]
# # Aufgabe 4.2 & 4.3
# Im Notizbuch "model.ipynb" habe ich ebenfalls die precision (Genauigkeit), den recall (Trefferquote) und den F1-Score berechnet:
# ![evaluation_4.2.png](attachment:evaluation_4.2.png)
#
# Die Werte "True Negative", "True Positive", "False Positive" und "False Negative" kann ich bei meinem Datensatz nicht berechnen, da in meinem Target (Spalte "winner") mehr als zwei Werte möglich sind (Schwarz, Weiss oder Untentschieden), und eben nicht nur True und False. Somit kann ich auch keine Wahrheitsmatrix erstellen. Den MSE kann ich ebenfalls nicht berechnen, da es keine numerischen Daten sind.

# %% [markdown]
# # Aufgabe 4.4
#
# Der Durchschnitt von allen Werten von precision, recall und f1-score beträgt 0.67 bis 0.68, was genau dem Score meines verwendeten Algorithmus entspricht.
#
# Die Spalte "victory_status" ist wahrscheinlich deswegen so aussagekräftig, weil der Wert in der Spalte "winner" immer "draw" beträgt, wenn der Wert in "victory_status" auch "draw" ist. Bei den Spalten "white_rating" und "black_rating" habe ich gemerkt, dass meistens die Person gewinnt, die einen viel höheren Wert als die andere hat. Aber ansonsten spielt in meinem Datensatz wahrscheinlich auch der Zufall eine grosse Rolle, weshalb das Modell noch lange nicht perfekt ist.
